# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from pandas import read_csv
df=read_csv('/Users/divyasaisomana/placement prediction system/data/placement_predict_50k Dataset_final.csv')

# %%
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns
categorical_features = df.select_dtypes(include=['object']).columns

print("Numerical Features:", list(numerical_features))
print("Categorical Features:", list(categorical_features))
# Out:
# Numerical Features: ['StudentID', 'SGPA_Sem1', 'SGPA_Sem2', 'SGPA_Sem3', 'SGPA_Sem4', 'SGPA_Sem5', 'SGPA_Sem6', 'SGPA_Sem7', 'SGPA_Sem8', 'CGPA', 'AttendancePercent', 'Internships', 'Projects', 'Workshops', 'Certifications', 'Publications', 'AptitudeTestScore', 'SoftSkillsRating', 'CodingTestScore', 'MockInterviewScore', 'ExtraCurricular', 'PlacementStatus', 'IsAnomaly', 'Salary Package']
# Categorical Features: ['Gender', 'City', 'CollegeTier', 'Stream', 'Specialisation', 'Hostel', 'HistoryOfBacklogs', 'CGPA_Tier']
# /var/folders/hf/y8bn0ltn3rq5yk4ns02xfn740000gn/T/ipykernel_3525/2351482356.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# ...

# %%
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns
categorical_features = df.select_dtypes(include=['object']).columns

print("Numerical Features:", list(numerical_features))
print("Categorical Features:", list(categorical_features))
# Out:
# Numerical Features: ['StudentID', 'SGPA_Sem1', 'SGPA_Sem2', 'SGPA_Sem3', 'SGPA_Sem4', 'SGPA_Sem5', 'SGPA_Sem6', 'SGPA_Sem7', 'SGPA_Sem8', 'CGPA', 'AttendancePercent', 'Internships', 'Projects', 'Workshops', 'Certifications', 'Publications', 'AptitudeTestScore', 'SoftSkillsRating', 'CodingTestScore', 'MockInterviewScore', 'ExtraCurricular', 'PlacementStatus', 'IsAnomaly', 'Salary Package']
# Categorical Features: ['Gender', 'City', 'CollegeTier', 'Stream', 'Specialisation', 'Hostel', 'HistoryOfBacklogs', 'CGPA_Tier']
# /var/folders/hf/y8bn0ltn3rq5yk4ns02xfn740000gn/T/ipykernel_3525/2351482356.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# ...

# %%
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns
categorical_features = df.select_dtypes(include=['object']).columns
# Out:
# /var/folders/hf/y8bn0ltn3rq5yk4ns02xfn740000gn/T/ipykernel_3525/2106737590.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_features = df.select_dtypes(include=['object']).columns

# %%
print("\n--- Correlation Matrix ---")
print('corr_matrix')
# Out:
# --- Correlation Matrix ---
# corr_matrix

# %%
# Create Correlation Heatmap

import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation matrix
corr_matrix = df.corr(numeric_only=True)

# Create figure
plt.figure(figsize=(15, 15))

# Create heatmap
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    vmin=-1,
    vmax=1,
    square=True,
    linewidths=0.5
)

plt.title(
    "Correlation Heatmap of Numerical Features",
    fontsize=14,
    fontweight="bold"
)

plt.tight_layout()
plt.show()# Create Correlation Heatmap

import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation matrix
corr_matrix = df.corr(numeric_only=True)

# Create figure
plt.figure(figsize=(15, 15))

# Create heatmap
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    vmin=-1,
    vmax=1,
    square=True,
    linewidths=0.5
)

plt.title(
    "Correlation Heatmap of Numerical Features",
    fontsize=14,
    fontweight="bold"
)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Create heatmap
plt.figure(figsize=(15, 15))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    vmin=-1,
    vmax=1,
    square=True,
    linewidths=0.5
)

plt.title(
    "Correlation Heatmap of Numerical Features",
    fontsize=14,
    fontweight="bold"
)

plt.tight_layout()

# Export Heatmap
output_dir = r"C:\KLH\Subjects\Y25-ML\practical\Placement-Prediction-System\outputs"

# Create outputs folder if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# File path
heatmap_path = os.path.join(
    output_dir,
    "correlation_heatmap.png"
)

# Save heatmap
plt.savefig(heatmap_path, dpi=300, bbox_inches="tight")

plt.show()
plt.close()

print(f"Exported heatmap to: {heatmap_path}")
# Out:
# Exported heatmap to: C:\KLH\Subjects\Y25-ML\practical\Placement-Prediction-System\outputs/correlation_heatmap.png

# %%
print(os.getcwd())
# Out:
# /Users/divyasaisomana/placement prediction system/notebooks

# %%
# 3. Produce Boxplots: Numerical Features vs PlacementStatus

import os
import matplotlib.pyplot as plt
import seaborn as sns

target_col = "PlacementStatus"

# Check whether target column exists
if target_col in df.columns:

    # Get numerical columns
    numerical_cols = df.select_dtypes(include="number").columns.tolist()

    # Remove target column if it happens to be numeric
    numerical_cols = [
        col for col in numerical_cols
        if col != target_col
    ]

    print("Numerical columns:", numerical_cols)

    # Make sure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Create boxplots
    for col in numerical_cols:

        plt.figure(figsize=(6, 5))

        sns.boxplot(
            data=df,
            x=target_col,
            y=col
        )

        plt.title(
            f"{col} vs {target_col}",
            fontsize=12,
            fontweight="bold"
        )

        plt.xlabel(target_col)
        plt.ylabel(col)

        plt.tight_layout()

        # Create filename
        boxplot_filename = f"boxplot_{col}_vs_{target_col}.png"

        # Create complete path
        boxplot_path = os.path.join(
            output_dir,
            boxplot_filename
        )

        # Save figure
        plt.savefig(
            boxplot_path,
            dpi=300,
            bbox_inches="tight"
        )

        plt.show()
        plt.close()

        print(f"Exported boxplot to: {boxplot_path}")

else:
    print(
        f"\nTarget column '{target_col}' "
        "not found in dataset. Skipping boxplots."
    )

print("\nAll EDA tasks completed successfully!")
# Out:
# Numerical columns: ['StudentID', 'SGPA_Sem1', 'SGPA_Sem2', 'SGPA_Sem3', 'SGPA_Sem4', 'SGPA_Sem5', 'SGPA_Sem6', 'SGPA_Sem7', 'SGPA_Sem8', 'CGPA', 'AttendancePercent', 'Internships', 'Projects', 'Workshops', 'Certifications', 'Publications', 'AptitudeTestScore', 'SoftSkillsRating', 'CodingTestScore', 'MockInterviewScore', 'ExtraCurricular', 'IsAnomaly', 'Salary Package']
# Exported boxplot to: C:\KLH\Subjects\Y25-ML\practical\Placement-Prediction-System\outputs/boxplot_StudentID_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\Y25-ML\practical\Placement-Prediction-System\outputs/boxplot_SGPA_Sem1_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\Y25-ML\practical\Placement-Prediction-System\outputs/boxplot_SGPA_Sem2_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\Y25-ML\practical\Placement-Prediction-System\outputs/boxplot_SGPA_Sem3_vs_PlacementStatus.png
# ...

# %%
numerical_columns = df.select_dtypes(include="number").columns.tolist()

print("Numerical columns:")
print(numerical_columns)

df[numerical_columns].boxplot(figsize=(14, 8))

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Numerical columns:
# ['StudentID', 'SGPA_Sem1', 'SGPA_Sem2', 'SGPA_Sem3', 'SGPA_Sem4', 'SGPA_Sem5', 'SGPA_Sem6', 'SGPA_Sem7', 'SGPA_Sem8', 'CGPA', 'AttendancePercent', 'Internships', 'Projects', 'Workshops', 'Certifications', 'Publications', 'AptitudeTestScore', 'SoftSkillsRating', 'CodingTestScore', 'MockInterviewScore', 'ExtraCurricular', 'PlacementStatus', 'IsAnomaly', 'Salary Package']

# %%
target_col = "PlacementStatus"
feature_col = "Certifications"

fig7 = sns.boxplot(
    x=target_col,
    y=feature_col,
    data=df
)

plt.xlabel(target_col)
plt.ylabel(feature_col)
plt.title(f"{feature_col} vs {target_col}")

plt.tight_layout()
plt.show()
