# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from pandas import read_csv
df=read_csv(r'/Users/divyasaisomana/placement prediction system/data/titanic.csv')

# %%
numerical_features = df.select_dtypes(include=[np.number]).columns.tolist()
corr_matrix = df[numerical_features].corr()

# %%
print("\n---Correlation Matrix---")
print(corr_matrix)
# Out:
# ---Correlation Matrix---
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
print("\n---Correlation Matrix---")
print(corr_matrix)
# Out:
# ---Correlation Matrix---
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
sns.heatmap(
corr_matrix,
annot=True,
cmap="coolwarm",
fmt=".2f",
vmin=-1,
vmax=1,
square=True,
linewidths=0.5
)
plt.title("Correlation Heatmap of Numerical Features", fontsize=20, fontweight="bold")
plt.tight_layout()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
sns.heatmap(
corr_matrix,
annot=True,
cmap="coolwarm",
fmt=".2f",
vmin=-1,
vmax=1,
square=True,
linewidths=0.5
)
plt.title("Correlation Heatmap of Numerical Features", fontsize=14, fontweight="bold")
plt.tight_layout()

# Export Heatmap
import os
output_dir = r"C:\Users\divyasaisomana\placement prediction system\outputs"
os.makedirs(output_dir, exist_ok=True)
heatmap_path = os.path.join(output_dir, "correlation_heatmap.png")
plt.savefig(heatmap_path, dpi=300)
plt.close()
print(f"Exported heatmap to: {heatmap_path}")
# Out:
# Exported heatmap to: C:\Users\divyasaisomana\placement prediction system\outputs/correlation_heatmap.png

# %%
print(os.getcwd())
# Out:
# /Users/divyasaisomana/placement prediction system/notebooks/skill

# %%
target_col = "PassengerId"
if target_col in df.columns:
    for col in numerical_features:
        plt.figure(figsize=(6, 5))
        sns.boxplot(
            x=target_col,
            y=col,
            data=df,
            palette="Set2",
            hue=target_col,
            legend=False
        )
        plt.title(f"{col} vs {target_col}", fontsize=12, fontweight="bold")
        plt.xlabel(target_col)
        plt.ylabel(col)
        plt.tight_layout()
        

        # Save the boxplot
        boxplot_filename = f"boxplot_{col}_vs_{target_col}.png"

        # Create complete file path
        boxplot_path = os.path.join(output_dir, boxplot_filename)

        # Save the figure
        plt.savefig(boxplot_path,    dpi=300,    bbox_inches="tight")

        # Close the figure
        plt.close()

        # Display confirmation message
        print(f"Exported boxplot to: {boxplot_path}")

    else:
        print(f"\nTarget column '{target_col}' not found in dataset. Skipping boxplots.")

        print("\nAll EDA tasks completed successfully!")
# Out:
# Exported boxplot to: C:\Users\divyasaisomana\placement prediction system\outputs/boxplot_PassengerId_vs_PassengerId.png
# Exported boxplot to: C:\Users\divyasaisomana\placement prediction system\outputs/boxplot_Survived_vs_PassengerId.png
# Exported boxplot to: C:\Users\divyasaisomana\placement prediction system\outputs/boxplot_Pclass_vs_PassengerId.png
# Exported boxplot to: C:\Users\divyasaisomana\placement prediction system\outputs/boxplot_Age_vs_PassengerId.png
# Exported boxplot to: C:\Users\divyasaisomana\placement prediction system\outputs/boxplot_SibSp_vs_PassengerId.png
# Exported boxplot to: C:\Users\divyasaisomana\placement prediction system\outputs/boxplot_Parch_vs_PassengerId.png
# Exported boxplot to: C:\Users\divyasaisomana\placement prediction system\outputs/boxplot_Fare_vs_PassengerId.png
#
# Target column 'PassengerId' not found in dataset. Skipping boxplots.
#
# All EDA tasks completed successfully!
